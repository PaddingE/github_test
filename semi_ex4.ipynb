# %%
import pandas as pd
import numpy as np

# %%
df_data1 = pd.read_excel('./전국_연령별_장애유형별_성별_등록장애인수_20230515034425.xlsx')
df_data2 = pd.read_excel('./전국_연령별_장애유형별_성별_등록장애인수_20230515034348.xlsx')
df_data3 = pd.read_excel('./전국_연령별_장애유형별_성별_등록장애인수_20230515033734.xlsx')

# %%
print(df_data1.shape)

df_data1

df_data1_short_2017 = df_data1.loc[:26,'2017']
df_data1_short_2018 = df_data1.loc[:26,'2018']

df_data1_short_2017
df_data1_short_2018

df_data1_short = pd.concat([df_data1_short_2017,df_data1_short_2018], axis= 1)

print(df_data1_short)
# Out:
# (150, 98)
#        2017     2018
# 0        합계       합계
# 1         계        계
# 2   2545637  2585876
# 3      5673     5875
# 4        46       41
# 5       517      482
# 6      1157     1066
# 7      1640     1804
# 8      2313     2482
# 9     21583    23334
# 10     3310     3300
# 11     4637     4865
# 12     4835     5349
# 13     4365     5178
# 14     4436     4642
# 15    24178    24253
# 16     4927     4694
# 17     4288     5137
# 18     4481     4527
# 19     4979     4680
# 20     5503     5215
# 21    38352    36606
# 22     5981     5803
# 23     6699     6313
# 24     8146     7040
# 25     8477     8622
# 26     9049     8828

# %%
print(df_data2.shape)

df_data2_short = df_data2.loc[:26,['2019','2020']]

df_data2_short
# Out:
# (153, 98)
#        2019     2020
# 0        합계       합계
# 1         계        계
# 2   2618918  2633026
# 3      6159     5772
# 4        43       36
# 5       483      381
# 6      1014      916
# 7      1721     1614
# 8      2898     2825
# 9     24961    25793
# 10     3520     3957
# 11     4658     4786
# 12     5572     5156
# 13     5773     5869
# 14     5438     6025
# 15    24925    26554
# 16     4888     5649
# 17     4951     5083
# 18     5407     5201
# 19     4789     5635
# 20     4890     4986
# 21    34723    32056
# 22     5508     5165
# 23     6127     5794
# 24     6682     6404
# 25     7448     6996
# 26     8958     7697

# %%
df_data3_short = df_data3.loc[:26,['2021','2022']]

df_data3_short
# Out:
#        2021     2022
# 0        합계       합계
# 1         계        계
# 2   2644700  2652860
# 3      5571     5124
# 4        28       20
# 5       409      354
# 6       801      729
# 7      1599     1320
# 8      2734     2701
# 9     26733    28165
# 10     4121     4110
# 11     5591     6056
# 12     5449     6439
# 13     5449     5851
# 14     6123     5709
# 15    28866    30524
# 16     6279     6434
# 17     5911     6520
# 18     5348     6229
# 19     5442     5648
# 20     5886     5693
# 21    30818    30939
# 22     5266     6210
# 23     5484     5574
# 24     6041     5767
# 25     6754     6369
# 26     7273     7019

# %%
df_data_short = pd.concat([df_data1_short,df_data2_short,df_data3_short], axis= 1)

df_data_short
# Out:
#        2017     2018     2019     2020     2021     2022
# 0        합계       합계       합계       합계       합계       합계
# 1         계        계        계        계        계        계
# 2   2545637  2585876  2618918  2633026  2644700  2652860
# 3      5673     5875     6159     5772     5571     5124
# 4        46       41       43       36       28       20
# 5       517      482      483      381      409      354
# 6      1157     1066     1014      916      801      729
# 7      1640     1804     1721     1614     1599     1320
# 8      2313     2482     2898     2825     2734     2701
# 9     21583    23334    24961    25793    26733    28165
# 10     3310     3300     3520     3957     4121     4110
# 11     4637     4865     4658     4786     5591     6056
# 12     4835     5349     5572     5156     5449     6439
# 13     4365     5178     5773     5869     5449     5851
# 14     4436     4642     5438     6025     6123     5709
# 15    24178    24253    24925    26554    28866    30524
# 16     4927     4694     4888     5649     6279     6434
# 17     4288     5137     4951     5083     5911     6520
# 18     4481     4527     5407     5201     5348     6229
# 19     4979     4680     4789     5635     5442     5648
# 20     5503     5215     4890     4986     5886     5693
# 21    38352    36606    34723    32056    30818    30939
# 22     5981     5803     5508     5165     5266     6210
# 23     6699     6313     6127     5794     5484     5574
# 24     8146     7040     6682     6404     6041     5767
# 25     8477     8622     7448     6996     6754     6369
# 26     9049     8828     8958     7697     7273     7019

# %%
df_data_short.iloc[3]
# Out:
# 2017    5673
# 2018    5875
# 2019    6159
# 2020    5772
# 2021    5571
# 2022    5124
# Name: 3, dtype: object

# %%
df1 = df_data_short.iloc[3]
df2 = df_data_short.iloc[9]
df3 = df_data_short.iloc[15]
df4 = df_data_short.iloc[21]

df_total = df_data_short.iloc[3] + df_data_short.iloc[9] + df_data_short.iloc[15] + df_data_short.iloc[21]


df_data_final = pd.concat([df1 , df2 , df3,df4],axis= 1)

df_total
# Out:
# 2017    89786
# 2018    90068
# 2019    90768
# 2020    90175
# 2021    91988
# 2022    94752
# dtype: object

# %%
df_total = df_data_short.iloc[3] + df_data_short.iloc[9] + df_data_short.iloc[15] + df_data_short.iloc[21]

df1 = df_data_short.iloc[3] / df_total * 100
df2 = df_data_short.iloc[9] / df_total * 100
df3 = df_data_short.iloc[15] / df_total * 100
df4 = df_data_short.iloc[21] / df_total * 100

df_data_final = pd.concat([df1 , df2 , df3,df4],axis= 1)
df = df_data_final.T
df
# Out:
#         2017       2018       2019       2020       2021       2022
# 0   6.318357   6.522849   6.785431   6.400887   6.056225   5.407801
# 1  24.038269  25.907092   27.49978  28.603271  29.061399  29.724966
# 2  26.928474  26.927433  27.460118  29.447186   31.38018  32.214623
# 3    42.7149  40.642626  38.254671  35.548655  33.502196  32.652609

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.plot(df1, marker='o',label = ['1-4'])
plt.plot(df2, marker='o',label = ['5-9'])
plt.plot(df3, marker='o',label = ['10-14'])
plt.plot(df4, marker='o',label = ['15-19'])
plt.xlabel('year')
plt.ylabel('ratio')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(4, 1, figsize=(10, 10))

ax[0].plot(df1, 'ro-', label='1-4')
ax[1].plot(df2, 'ro-', label='5-9')
ax[2].plot(df3, 'ro-', label='10-14')
ax[3].plot(df4, 'ro-', label='15-19')

ax[0].set_xlabel('year')
ax[1].set_xlabel('year')
ax[2].set_xlabel('year')
ax[3].set_xlabel('year')
ax[0].set_ylabel('ratio')
ax[1].set_ylabel('ratio')
ax[2].set_ylabel('ratio')
ax[3].set_ylabel('ratio')
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

# 그래프 출력
plt.show()

# %%
df_data_all = pd.read_excel('./201712_202212_연령별인구현황_연간.xlsx', header= 3)

df_data_all
# Out:
#         행정기관코드       행정기관       총 인구수    연령구간인구수       0~9세     10~19세
# 0            0       전국      51778544    9739623    4435198    5304425  \
# 1   1100000000    서울특별시       9857426  1,623,118    728,462    894,656
# 2   2600000000    부산광역시     3,470,653    568,776    258,732    310,044
# 3   2700000000    대구광역시     2,475,231    462,799    201,043    261,756
# 4   2800000000    인천광역시     2,948,542    561,488    259,925    301,563
# 5   2900000000    광주광역시     1,463,770    315,680    135,873    179,807
# 6   3000000000    대전광역시     1,502,227    303,223    135,218    168,005
# 7   3100000000    울산광역시     1,165,132    239,335    112,441    126,894
# 8   3600000000  세종특별자치시       280,100     72,235     40,172     32,063
# 9   4100000000      경기도    12,873,895  2,637,136  1,226,500  1,410,636
# 10  4200000000      강원도     1,550,142    273,672    116,726    156,946
# 11  4300000000     충청북도     1,594,432    303,032    137,206    165,826
# 12  4400000000     충청남도     2,116,770    412,335    193,878    218,457
# 13  4500000000     전라북도     1,854,607    350,773    150,817    199,956
# 14  4600000000     전라남도     1,896,424    342,874    151,229    191,645
# 15  4700000000     경상북도     2,691,706    469,847    215,451    254,396
# 16  4800000000     경상남도     3,380,404    664,317    307,415    356,902
# 17  5000000000  제주특별자치도       657,083    138,983     64,110     74,873
#
#         남 인구수  연령구간인구수.1   0~9세.1 10~19세.1  ...    0~9세.15  10~19세.15
# 0    25855919    5035540  2277849  2757691  ...    3532642    4703196  \
# 1   4,830,206    834,950  373,353  461,597  ...    545,317    749,118
# 2   1,709,508    294,700  132,924  161,776  ...    206,377    265,934
# 3   1,227,814    241,325  103,263  138,062  ...    157,730    217,532
# 4   1,479,597    289,024  133,221  155,803  ...    208,942    272,740
# 5     725,295    163,517   69,981   93,536  ...    106,977    150,857
# 6     750,969    157,003   69,670   87,333  ...    102,233    140,288
# 7     599,480    125,294   58,121   67,173  ...     85,061    110,202
# 8     139,734     36,665   20,501   16,164  ...     45,951     49,002
# 9   6,475,323  1,357,979  629,189  728,790  ...  1,040,954  1,327,726
# 10    780,635    142,027   59,835   82,192  ...     96,036    132,133
# 11    805,091    156,742   70,270   86,472  ...    109,410    145,882
# 12  1,076,270    213,362   99,537  113,825  ...    152,498    202,299
# 13    922,307    181,352   77,618  103,734  ...    110,400    167,541
# 14    948,290    177,222   77,420   99,802  ...    114,889    161,566
# 15  1,353,164    246,051  111,557  134,494  ...    165,119    220,579
# 16  1,701,413    346,046  158,371  187,675  ...    229,942    318,924
# 17    330,823     72,281   33,018   39,263  ...     54,806     70,873
#
#      총 인구수.14 연령구간인구수.16  0~9세.16 10~19세.16   총 인구수.15 연령구간인구수.17  0~9세.17
# 0    25636951    4233978  1810379   2423599   25802087    4001860  1722263  \
# 1   4,570,048    663,666  280,017   383,649  4,858,324    630,769  265,300
# 2   1,619,915    242,589  105,853   136,736  1,697,897    229,722  100,524
# 3   1,162,865    193,458   80,742   112,716  1,200,826    181,804   76,988
# 4   1,485,175    247,070  107,055   140,015  1,482,139    234,612  101,887
# 5     707,299    132,918   54,782    78,136    723,751    124,916   52,195
# 6     721,245    125,072   52,537    72,535    724,827    117,449   49,696
# 7     570,368    101,445   43,704    57,741    540,295     93,818   41,357
# 8     191,389     48,026   23,379    24,647    192,202     46,927   22,572
# 9   6,839,276  1,213,073  532,630   680,443  6,750,156  1,155,607  508,324
# 10    772,947    117,700   49,157    68,543    763,551    110,469   46,879
# 11    810,782    131,528   55,944    75,584    784,276    123,764   53,466
# 12  1,086,632    182,836   78,092   104,744  1,036,405    171,961   74,406
# 13    880,592    143,034   56,485    86,549    889,015    134,907   53,915
# 14    915,272    142,007   58,743    83,264    902,425    134,448   56,146
# 15  1,311,881    200,551   84,918   115,633  1,288,611    185,147   80,201
# 16  1,651,675    284,086  118,201   165,885  1,628,818    264,780  111,741
# 17    339,590     64,919   28,140    36,779    338,569     60,760   26,666
#
#    10~19세.17
# 0    2279597
# 1    365,469
# 2    129,198
# 3    104,816
# 4    132,725
# 5     72,721
# 6     67,753
# 7     52,461
# 8     24,355
# 9    647,283
# 10    63,590
# 11    70,298
# 12    97,555
# 13    80,992
# 14    78,302
# 15   104,946
# 16   153,039
# 17    34,094
#
# [18 rows x 74 columns]

# %%
df_data_sum_0_9 = df_data_all.iloc[0,4::12]
df_data_sum_10_19 = df_data_all.iloc[0,5::12]

print(df_data_sum_0_9)
print(df_data_sum_10_19)

list_sr = []

for i in range(len(df_data_sum_0_9)):
    data = df_data_sum_0_9[i] + df_data_sum_10_19[i]
    list_sr.append(data)
    
print(list_sr)
    




# df_data_sum = df_data_sum_0_9 + df_data_sum_10_19


# print(df_data_sum)
# Out:
# 0~9세       4435198
# 0~9세.3     4303062
# 0~9세.6     4166914
# 0~9세.9     3970070
# 0~9세.12    3760350
# 0~9세.15    3532642
# Name: 0, dtype: object
# 10~19세       5304425
# 10~19세.3     5131153
# 10~19세.6     4959010
# 10~19세.9     4793336
# 10~19세.12    4709316
# 10~19세.15    4703196
# Name: 0, dtype: object
# [9739623, 9434215, 9125924, 8763406, 8469666, 8235838]

# %%
list_index = ['2017','2018','2019','2020','2021','2022']

df_sum_all = pd.DataFrame(list_sr, index= list_index)

df_sum_all
# Out:
#             0
# 2017  9739623
# 2018  9434215
# 2019  9125924
# 2020  8763406
# 2021  8469666
# 2022  8235838

# %%
df1 = df_data_short.iloc[3]
df2 = df_data_short.iloc[9]
df3 = df_data_short.iloc[15]
df4 = df_data_short.iloc[21]

df_total = df_data_short.iloc[3] + df_data_short.iloc[9] + df_data_short.iloc[15] + df_data_short.iloc[21]


df_data_final = pd.concat([df1 , df2 , df3,df4],axis= 1)

df_total = pd.DataFrame(df_total)

df_total
# Out:
#           0
# 2017  89786
# 2018  90068
# 2019  90768
# 2020  90175
# 2021  91988
# 2022  94752

# %%
df_data_ratio = df_total / df_sum_all * 100

df_data_ratio
# Out:
#              0
# 2017  0.921863
# 2018  0.954695
# 2019  0.994617
# 2020  1.028995
# 2021  1.086088
# 2022  1.150484

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_data_ratio, marker='o')

plt.xlabel('year')
plt.ylabel('ratio')

plt.show()
